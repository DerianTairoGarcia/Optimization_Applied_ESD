# %% [markdown]
# ### Introducing while loops

# %%
# Counting to 5
current_number = 1
while current_number <= 5:
    print(current_number)
    current_number += 1

# %%
# Letting the User Choose When to Quit
prompt = "\nTell me something, and I will repeat it back to you:"
prompt += "\nEnter 'quit' to end the program. "

message = ""
while message != 'quit':
    message = input(prompt)
    print(message)

# %%
# Using a Flag
prompt = "\nTell me something, and I will repeat it back to you:"
prompt += "\nEnter 'quit' to end the program. "

indicator = True
while indicator:
    message = input(prompt)
    if message == 'quit':
        indicator = False
    else:
        print(message)

# %%
# Using break to Exit a Loop
prompt = "\nPlease enter the name of a city you have visited:"
prompt += "\n(Enter 'quit' when you are finished.) "

while True:
    city = input(prompt)
    if city == 'quit':
        break
    else:
        print(f"I'd love to go to " + city.title() + "!")
# Out:
# I'd love to go to Cusco!

# %% [markdown]
# ### Using a while Loop with Lists and Dictionaries

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Defining a function

# %%
def greet_user():
    """Display a simple greeting."""
    print("Hello!")

greet_user()
# Out:
# Hello!

# %%
def greet_user(username): # username is a parameter 
    print(f"Hello, {username.title()}!")
greet_user('derian') # derian is an argument
# Out:
# Hello, Derian!

# %%
def greet_user(username):
    print(f"Hello, {username.title()}!")
greet_user('carlos')
# Out:
# Hello, Carlos!

# %% [markdown]
# #### Try it yourself

# %%
def display_message():
    print("I'm learning about functions in this chapter.")
display_message()
# Out:
# I'm learning about functions in this chapter.

# %%
def favorite_book(title):
    print(f"One of my favorite books is {title.title()}.")
favorite_book('\'100 años de soledad\'')
# Out:
# One of my favorite books is '100 Años De Soledad'.

# %% [markdown]
# ### Passing Arguments

# %%
def describe_pet(animal_type, pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")
describe_pet('bunny', 'theo')
# Out:
# I have a bunny.
# My bunny's name is Theo.

# %%
def describe_pet(animal_type, pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")
describe_pet('bunny', 'theo')
describe_pet('dog', 'pepe')
# Out:
# I have a bunny.
# My bunny's name is Theo.
#
# I have a dog.
# My dog's name is Pepe.

# %%
# if  a change the order of the arguments, the output will change?
def describe_pet(animal_type, pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")
describe_pet('theo', 'bunny')
# Out:
# I have a theo.
# My theo's name is Bunny.

# %%
def describe_pet(animal_type, pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")
describe_pet(pet_name='theo', animal_type='bunny') # keyword arguments
# Out:
# I have a bunny.
# My bunny's name is Theo.

# %%
def describe_pet(animal_type, pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")
describe_pet(pet_name='theo', animal_type='bunny')
describe_pet(animal_type='dog', pet_name='pepe')
# Out:
# I have a bunny.
# My bunny's name is Theo.
#
# I have a dog.
# My dog's name is Pepe.

# %%
def describe_pet(pet_name, animal_type='dog'):  # default values and note that order of the parameters is important
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")
describe_pet(pet_name='pepe')
# Out:
# I have a dog.
# My dog's name is Pepe.

# %%
describe_pet('pepe')
# Out:
# I have a dog.
# My dog's name is Pepe.

# %%
describe_pet(pet_name='pepe', animal_type='cat')
# Out:
# I have a cat.
# My cat's name is Pepe.

# %% [markdown]
# #### Try it yourself

# %%
def make_shirt(size, message):
    print(f"The size of the shirt is {size.title()} and the message is {message.title()}.")
make_shirt('M', 'I love Python')
# Out:
# The size of the shirt is M and the message is I Love Python.

# %%
make_shirt(message='I love programming', size='L')
# Out:
# The size of the shirt is L and the message is I Love Programming.

# %%
make_shirt('s', 'I love read')
# Out:
# The size of the shirt is S and the message is I Love Read.

# %%
def make_shirt(size='L', message='I love Python'):
    print(f"The large size of the shirt is {size.title()} and the message is {message.title()}.")
make_shirt()
# Out:
# The large size of the shirt is L and the message is I Love Python.

# %%
make_shirt('M')
# Out:
# The large size of the shirt is M and the message is I Love Python.

# %%
make_shirt('S', 'I love programming')
# Out:
# The large size of the shirt is S and the message is I Love Programming.

# %%
def describe_city(city, country='Perú'):
    print(f"{city.title()} is in {country.title()}")

# %%
describe_city('Lima')
# Out:
# Lima is in Perú

# %%
describe_city('Cusco')
# Out:
# Cusco is in Perú

# %%
describe_city('São Paulo', 'Brazil')
# Out:
# São Paulo is in Brazil

# %% [markdown]
# ### Return Values

# %%
def get_formatted_name(first_name, last_name):
    full_name = f"{first_name} {last_name}"
    return full_name.title()

musician = get_formatted_name('paco', 'de lucia')
print(musician)
# Out:
# Paco De Lucia

# %%
def get_formatted_name(first_name, middle_name, last_name):
    full_name = f"{first_name} {middle_name} {last_name}"
    return full_name.title()
musician = get_formatted_name('john', 'lee', 'hooker')
print(musician)
# Out:
# John Lee Hooker

# %%
def get_formatted_name(first_name, last_name, middle_name=''):
    if middle_name:
        full_name = f"{first_name} {middle_name} {last_name}"
    else:
        full_name = f"{first_name} {last_name}"
    return full_name.title()
musician = get_formatted_name('Paco', 'de lucia')
print(musician)
# Out:
# Paco De Lucia

# %%
musician = get_formatted_name('Paco', 'de lucia', 'juan')
print(musician)
# Out:
# Paco Juan De Lucia

# %%
musician = get_formatted_name('Paco', 'juan', 'de lucia')
print(musician)
# Out:
# Paco De Lucia Juan

# %%
def build_person(first_name, last_name):
    person = {'first': first_name, 'last': last_name}
    return person
musician = build_person('jimi', 'hendrix')
print(musician)
# Out:
# {'first': 'jimi', 'last': 'hendrix'}

# %%
def build_person(first_name, last_name, age=''):
    person = {'first': first_name, 'last': last_name}
    if age:
        person['age'] = age
    return person
musician = build_person('jimi', 'hendrix', age=27)
print(musician)
# Out:
# {'first': 'jimi', 'last': 'hendrix', 'age': 27}

# %%
def get_formatted_name(first_name, last_name):
    full_name = f"{first_name} {last_name}"
    return full_name.title()

# This is an infinite loop!
# while True:
    print("\nPlease tell me your name:")
    f_name = input("First name: ")
    l_name = input("Last name: ")

    formatted_name = get_formatted_name(f_name, l_name)
    print(f"\nHello, {formatted_name}!")
# Out:
# Please tell me your name:
#
# Hello,  !
#
# Please tell me your name:
#
# Hello,  !
#
# Please tell me your name:
#
# Hello,  !
#
# Please tell me your name:
#
# Hello,  !
#
# Please tell me your name:

# %%
def get_formatted_name(first_name, last_name):
    full_name = f"{first_name} {last_name}"
    return full_name.title()
while True:
    print("\n Please tell me your name:")
    print("(enter 'q' at any time to quit)")

    f_name = input("First name: ")
    if f_name == 'q':
        break
    l_name = input("Last name: ")
    if l_name == 'q':
        break

    formatted_name = get_formatted_name(f_name, l_name)
    print(f"\nHello, {formatted_name}!")
# Out:
# Please tell me your name:
# (enter 'q' at any time to quit)
#
# Hello, Derian Tairo!
#
# Please tell me your name:
# (enter 'q' at any time to quit)

# %% [markdown]
# #### Try it yourself

# %%
def city_country(city, country):
    return f"{city.title()}, {country.title()}"
location = city_country('Urcos', 'Quispicanchi')
print(location)
# Out:
# Urcos, Quispicanchi

# %%
def make_album(artist, title):
    album = {'artist': artist, 'title': title}
    return album
album_1 = make_album('Amy Winehouse', 'Back to Black')
print(album_1)
# Out:
# {'artist': 'Amy Winehouse', 'title': 'Back to Black'}

# %%
album_2 = make_album('The Beatles', 'Abbey Road')
print(album_2)
# Out:
# {'artist': 'The Beatles', 'title': 'Abbey Road'}

# %%
def make_album(artist, title, tracks=None):
    album = {'artist': artist, 'title': title}
    if tracks:
        album['tracks'] = tracks
    return album
album_1 = make_album('Amy Winehouse', 'Back to Black')
print(album_1)
# Out:
# {'artist': 'Amy Winehouse', 'title': 'Back to Black'}

# %%
album_2 = make_album('The Beatles', 'Abbey Road', tracks=17)
print(album_2)
# Out:
# {'artist': 'The Beatles', 'title': 'Abbey Road', 'tracks': 17}

# %%
def get_formatted_name(first_name, last_name):
    full_name = f"{first_name} {last_name}"
    return full_name.title()
while True:
    print("\n Please tell me your name:")
    print("(enter 'q' at any time to quit)")

    f_name = input("First name: ")
    if f_name == 'q':
        break
    
    l_name = input("Last name: ")
    if l_name == 'q':
        break

    formatted_name = get_formatted_name(f_name, l_name)
    print(f"\nHello, {formatted_name}!")
# Out:
#  Please tell me your name:
# (enter 'q' at any time to quit)
#
# Hello, Derian Tairo!
#
#  Please tell me your name:
# (enter 'q' at any time to quit)

# %%
def make_album(artist, song, tracks=None):
    album = {'Artist': artist, 'Song': song}
    return album

while True:
    print("\n Please enter an artist and song:")
    print("(enter 'q' at any time to quit)")

    a_name = input("Artist's name: ")
    if a_name == 'q':
        break
    t_name = input("Song's name: ")
    if t_name == 'q':
        break

album_complete = make_album(a_name, t_name)
print(f"The Artist's name is {album_complete}")
# Out:
#  Please enter an artist and song:
#
#  (enter 'q' at any time to quit)
#
#  Please enter an artist and song:
#
#  (enter 'q' at any time to quit)
#
#  Please enter an artist and song:
#
#  (enter 'q' at any time to quit)
# The Artist's name is {'Artist': 'q', 'Song': ''}

# %% [markdown]
# ### Passing a List

# %%
def greet_users(names):
    for name in names:    #name can be any name or word
        msg = f"Hello, {name.title()}!"
        print(msg)

# %%
usernames = ['Melvi', 'Alvaro', 'luis']
greet_users(usernames)
# Out:
# Hello, Melvi!
# Hello, Alvaro!
# Hello, Luis!

# %% [markdown]
# #### Modifying a List in a Function

# %%
unprinted_designs = ['iphone case', 'samsung case', 'motorola case']
completed_models = []

while unprinted_designs:
    current_design = unprinted_designs.pop()
    print(f"Printing model: {current_design}")
    completed_models.append(current_design)
# Out:
# Printing model: motorola case
# Printing model: samsung case
# Printing model: iphone case

# %%
print("\nThe following models have been printed:")
for completed_model in completed_models: #completed_model can be any name or word
    print(completed_model)
# Out:
# The following models have been printed:
# motorola case
# samsung case
# iphone case

# %%
def print_models(unprinted_designs, completed_models):
    while unprinted_designs:
        current_design = unprinted_designs.pop()
        print(f"Printing model: {current_design}")
        completed_models.append(current_design)

def show_completed_models(completed_models):
    print("\nThe following models have been printed:")
    for completed_model in completed_models:
        print(completed_model)

unprinted_designs = ['iphone case', 'samsung case', 'motorola case']
completed_models = []

print_models(unprinted_designs, completed_models)
show_completed_models(completed_models)
# Out:
# Printing model: motorola case
# Printing model: samsung case
# Printing model: iphone case
#
# The following models have been printed:
# motorola case
# samsung case
# iphone case

# %% [markdown]
# #### Try it Yourself

# %%
acronyms_list = ['lol', 'brb', 'smh', 'lmao', 'rofl']
def show_acronyms(acronyms):
    for acronym in acronyms:
        print(f'Acronym: {acronym}')

show_acronyms(acronyms_list)
# Out:
# Acronym: lol
# Acronym: brb
# Acronym: smh
# Acronym: lmao
# Acronym: rofl

# %%
messages_list = ['hello', 'how are you?', 'goodbye']
def show_messages(messages):
    for m in messages:
        msg = f'showing message: {m}'
        print(msg)
show_messages(messages_list)
# Out:
# showing message: hello
# showing message: how are you?
# showing message: goodbye

# %%
print_messages = ['hello', 'how are you?', 'goodbye']
sent_messages = []

def send_messages(print_messages, sent_messages):
    while print_messages:
        current_message = print_messages.pop()
        print(f"Sending message: {current_message}")
        sent_messages.append(current_message)

send_messages(print_messages, sent_messages)
print(print_messages)
print(sent_messages)
# Out:
# Sending message: goodbye
# Sending message: how are you?
# Sending message: hello
# []
# ['goodbye', 'how are you?', 'hello']

# %%
print_messages = ['hello', 'how are you?', 'goodbye']
sent_messages = []

def send_messages(print_messages, sent_messages):
    while print_messages:
        current_message = print_messages.pop()
        print(f"Sending message: {current_message}")
        sent_messages.append(current_message)

send_messages(print_messages[:], sent_messages)
print(print_messages)
print(sent_messages)
# Out:
# Sending message: goodbye
# Sending message: how are you?
# Sending message: hello
# ['hello', 'how are you?', 'goodbye']
# ['goodbye', 'how are you?', 'hello']

# %% [markdown]
# #### Passing an Arbitrary Number of Arguments

# %%
# The asterisk in the parameter name tells Python to make an empty tuple called toppings.
def make_pizza(*toppings):  
    print(toppings)
make_pizza('pepperoni')
make_pizza('mushrooms', 'green peppers', 'extra cheese')
# Out:
# ('pepperoni',)
# ('mushrooms', 'green peppers', 'extra cheese')

# %%
def make_pizza(*toppings):
    print("\nMaking a pizza with the following toppings:")
    for topping in toppings:
        print(f"- {topping}")

# %%
make_pizza('pepperoni')
make_pizza('pepperoni', 'mushrooms', 'green peppers', 'extra cheese')
# Out:
# Making a pizza with the following toppings:
# - pepperoni
#
# Making a pizza with the following toppings:
# - pepperoni
# - mushrooms
# - green peppers
# - extra cheese

# %% [markdown]
# #### Mixing Positional and Arbitrary Arguments

# %%
def make_pizza(size, *toppings):
    print(f"\nMaking a {size}-inch pizza with the following toppings:")
    for topping in toppings:
        print(f"- {topping}")
make_pizza(16, 'pepperoni')
# Out:
# Making a 16-inch pizza with the following toppings:
# - pepperoni

# %%
make_pizza(12, 'mushrooms', 'green peppers', 'extra cheese')
# Out:
# Making a 12-inch pizza with the following toppings:
# - mushrooms
# - green peppers
# - extra cheese

# %% [markdown]
# #### Using Arbitrary Keyword Arguments

# %%
def build_profile(first, last, **user_info): # ** creates an empty dictionary called user_info.
    user_info['first_name'] = first
    user_info['last_name'] = last
    return user_info
user_profile = build_profile('albert', 'einstein', location='princeton', field='physics')
print(user_profile)
# Out:
# {'location': 'princeton', 'field': 'physics', 'first_name': 'albert', 'last_name': 'einstein'}

# %% [markdown]
# ##### Try It Yourself

# %%
def sandwich(*ingredients):
    print("\nMaking a sandwich with the following ingredients:")
    for ingredient in ingredients:
        print(f"- {ingredient}")
sandwich('ham', 'cheese', 'lettuce')
# Out:
# Making a sandwich with the following ingredients:
# - ham
# - cheese
# - lettuce

# %%
sandwich('turkey', 'bacon', 'tomato', 'mayo')
# Out:
# Making a sandwich with the following ingredients:
# - turkey
# - bacon
# - tomato
# - mayo

# %%
def build_profile_myself(first, last, **user_info):
    user_info['first_name'] = first
    user_info['last_name'] = last
    return user_info
user_profile = build_profile_myself('derian', 'tairo', location='cusco', field='electrical engineering')
print(user_profile)
# Out:
# {'location': 'cusco', 'field': 'electrical engineering', 'first_name': 'derian', 'last_name': 'tairo'}

# %%
def car_info(manufacturer, model, **car_info):
    car_info['manufacturer'] = manufacturer
    car_info['model'] = model
    return car_info
car = car_info('subaru', 'outback', color='blue', tow_package= 'true')
print(car)
# Out:
# {'color': 'blue', 'tow_package': 'true', 'manufacturer': 'subaru', 'model': 'outback'}

# %% [markdown]
# #### Storing Your Functions in Modules

# %%
# See the Storing_functions_in_modules's file

# %% [markdown]
# #### Bibliography
#
# Python Crash Course, Third Edition.
#
# - [Link](https://nostarch.com/python-crash-course-3rd-edition)
#
# - [Link 2](https://ehmatthes.github.io/pcc_3e/)
#
# - [GitHub](https://github.com/ehmatthes/pcc_3e/)
